# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorAbraham/3D-portfolio-project/blob/main/label.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
cancer_data = pd.read_csv('/content/Cancer_Data.csv')

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0    842302         M        17.99  ...          0.4601                  0.11890          NaN
# 1    842517         M        20.57  ...          0.2750                  0.08902          NaN
# 2  84300903         M        19.69  ...          0.3613                  0.08758          NaN
# 3  84348301         M        11.42  ...          0.6638                  0.17300          NaN
# 4  84358402         M        20.29  ...          0.2364                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
# findining the count if different labels
cancer_data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
# load the label encoder function
label_encode = LabelEncoder()

# %%
labels=label_encode.fit_transform(cancer_data.diagnosis)

# %%
# appending the labels to the DataFrame

# %%
cancer_data['target'] = labels

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  ...  fractal_dimension_worst  Unnamed: 32  target
# 0    842302         M        17.99  ...                  0.11890          NaN       1
# 1    842517         M        20.57  ...                  0.08902          NaN       1
# 2  84300903         M        19.69  ...                  0.08758          NaN       1
# 3  84348301         M        11.42  ...                  0.17300          NaN       1
# 4  84358402         M        20.29  ...                  0.07678          NaN       1
#
# [5 rows x 34 columns]

# %%
cancer_data['target'].value_counts()
# Out:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
iris_data = pd.read_csv('/content/Iris.csv')

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
labels=label_encode.fit_transform(iris_data.Species)

# %%
iris_data['target'] = labels

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  target
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa       0
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa       0
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa       0
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa       0
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa       0

# %%
iris_data['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64
